# %%
class Node:
    def _init_(self,data):
        self.data=data
        self.left=None
        self.right=None
#inserting element into bst non-recursively
def insert(root,data):
    newnode=Node(data)
    x=root
    y=None
    while(x!=None):
        y=x
        if(data<x.data):
            x=x.left
        else:
            x=x.right
    if(y==None):
        y=newnode
    elif(data<y.data):
        y.left=newnode
    else:
        y.rigth=newnode
    return y
#inserting element into bst recursively
def insert(root,data):
    if root==None:
        return Node(data)
    if(root.data<data):
        root.right=insert(root.right,data)
    else:
        root.left=insert(root.left,data)
    return root
#searching element in bst
def search(root,key):
    if(root==None):
        return False
    if(root.data==key):
        return True
    if(root.data<key):
        return search(root.right,key)
    return search(root.left,key)
#preorder in bst
def preorder(root):
    if root==None:
        return
    print(root.data)
    preorder(root.left)
    preorder(root.right)
#postorder in bst
def postorder(root):
    if(root==None):
        return
    postorder(root.left)
    postorder(root.right)
    print(root.data)
#inorder in bst
def inorder(root):
    if(root==None):
        return
    inorder(root.left)
    print(root.data)
    inorder(root.right)
#levelorder in bst
def levelorder(root):
    queue=[]
    queue.append(root);
    while(len(queue)!=0):
        top=queue.pop(0)
        print(top.data)
        if(top.left!=None):
            queue.append(top.left)
        if(top.right!=None):
            queue.append(top.right)
root=None
root=insert(root,5)
root=insert(root,3)
root=insert(root,2)
root=insert(root,7)
root=insert(root,8)
if(search(root,7)):
    print("Key is present")
else:
    print("Key is not present")
print("Pre Order:")
print(preorder(root))
print("Post Order:")
print(postorder(root))
print("In Order:")
print(inorder(root))
print("Level Order:")
print(levelorder(root))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [1], line 75
#      73             queue.append(top.right)
#      74 root=None
# ---> 75 root=insert(root,5)
#      76 root=insert(root,3)
#      77 root=insert(root,2)
#
# Cell In [1], line 27, in insert(root, data)
#      25 def insert(root,data):
#      26     if root==None:
# ---> 27         return Node(data)
#      28     if(root.data<data):
#      29         root.right=insert(root.right,data)
#
# TypeError: Node() takes no arguments

# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.left = None
        self.right = None
def insert(root,data):
    if root is None:
        return Node(data)
    if root.data == data:
        return data
    elif root.data < data:
        root.right = insert(root.right,data)
    else:
        root.left = insert(root.left,data)
    return root
# def insert(root, data):
#     newnode = Node(data)
#     x = root
#     y = None
#     while (x != None):
#         y = x
#         if (data < x.data):
#             x = x.left
#         else:
#             x = x.right
#     if (y == None):
#         y = newnode
#     elif (data < y.data):
#         y.left = newnode
#     else:
#         y.right = newnode
#     return y

def inorder(root):
    if root:
        inorder(root.left)
        print(root.data,end = " ")
        inorder(root.right)

def preorder(root):
    if root:
        print(root.data,end = " ")
        preorder(root.left)
        preorder(root.right)

def postorder(root):
    if root:
        preorder(root.left)
        preorder(root.right)
        print(root.data,end = " ")
               
def levelorder(root):
    queue = []
    queue.append(root)
    while(len(queue) != 0):
        top = queue.pop(0)
        print(top.data,end = " ")
        if(top.left != None):
            queue.append(top.left)
        if(top.right != None):
            queue.append(top.right)
        
def search(root,data):
    if root is None:
        return root
    if root.data == data:
        return root.data
    elif root.data < data:
        return search(root.right,data)
    return search(root.left,data)


r = Node(100)
insert(r,50)
insert(r,20)
insert(r,30)
insert(r,10)
insert(r,40)
insert(r,80)

print("inorder ")
inorder(r)

print("\n")
print("preorder")
preorder(r)

print("\n")
print("post order")
postorder(r)

print('\n')
print("levelorder")
levelorder(r)

print('\n')
print("Search")
if search(r,40):
    print("found")
else:
    print("not found")
# Out:
# inorder
# 10 20 30 40 50 80 100
#
# preorder
# 100 50 20 10 30 40 80
#
# post order
# 50 20 10 30 40 80 100
#
# levelorder
# 100 50 20 80 10 30 40
#
# Search
# found
